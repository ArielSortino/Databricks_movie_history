# %%
bronze_folder_path = "abfss://bronze@moviee.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviee.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviee.dfs.core.windows.net"
bronze_inc_folder_path = "abfss://bronze-inc@moviee.dfs.core.windows.net"
silver_inc_folder_path = "abfss://silver-inc@moviee.dfs.core.windows.net"
gold_inc_folder_path = "abfss://gold-inc@moviee.dfs.core.windows.net"
