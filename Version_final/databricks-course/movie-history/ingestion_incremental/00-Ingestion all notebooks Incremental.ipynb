# %%
#### Este notebook es un clon del 00-Ingestion all notebooks Incremental de la carpeta ingestion, solo modifico que aca vamos a ejecutar todos los notebooks incrementales, y le tenemos que agregar la variable v_file_date para ver que fecha quiero ejecutar

# %%
v_result_1 = dbutils.notebook.run("01-Ingestion File movie Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_1

# %%
v_result_2 = dbutils.notebook.run("02-Ingestion File language Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_2

# %%
v_result_3 = dbutils.notebook.run("03-Ingestion File genre Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_3

# %%
v_result_4 = dbutils.notebook.run("04-Ingestion File country Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_4

# %%
v_result_5 = dbutils.notebook.run("05-Ingestion File person Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_5

# %%
v_result_6 = dbutils.notebook.run("06-Ingestion File movie_genre Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_6

# %%
v_result_7 = dbutils.notebook.run("07-Ingestion File movie_cast Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_7

# %%
v_result_8 = dbutils.notebook.run("08-Ingestion File language_role Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_8

# %%
v_result_9 = dbutils.notebook.run("09-Ingestion Folder production_company Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_9

# %%
v_result_10 = dbutils.notebook.run("10-Ingestion Folder movie_company Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_10

# %%
v_result_11 = dbutils.notebook.run("11-Ingestion Folder movie_language Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_11

# %%
v_result_12 = dbutils.notebook.run("12-Ingestion Folder production_country Incremental", 0, {"p_environment" : "developer", "v_file_date" : "2024-12-16"})

# %%
v_result_12
