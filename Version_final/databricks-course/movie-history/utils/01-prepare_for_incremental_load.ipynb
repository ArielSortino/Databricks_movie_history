-- %%
DROP DATABASE IF EXISTS movie_bronze_inc CASCADE

-- %%
CREATE SCHEMA IF NOT EXISTS movie_bronze_inc
MANAGED LOCATION "abfss://bronze-inc@moviee.dfs.core.windows.net"

-- %%
DROP DATABASE IF EXISTS movie_silver_inc CASCADE

-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver_inc
MANAGED LOCATION "abfss://silver-inc@moviee.dfs.core.windows.net"

-- %%
DROP DATABASE IF EXISTS movie_gold_inc CASCADE

-- %%
CREATE SCHEMA IF NOT EXISTS movie_gold_inc
MANAGED LOCATION "abfss://gold-inc@moviee.dfs.core.windows.net"
