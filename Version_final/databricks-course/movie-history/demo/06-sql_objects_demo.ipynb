-- %% [markdown]
-- ### Base de Datos(Database)

-- %% [markdown]
-- ### Objetivos
-- 1. Crear la Base de Datos "Demo"
-- 2. Comando "SHOW"
-- 3. Comando DESCRIBE(DESC)
-- 4. Mostrar la Base de Datos Actual
--
-- #### Hay más documentación en https://spark.apache.org/docs/latest/sql-ref-syntax.html
-- #### Como es todo sql pongo el lenguaje SQL por defecto en todo el notebook

-- %%
CREATE SCHEMA IF NOT EXISTS demo;

-- %%
SHOW DATABASES;

-- %%
DESCRIBE DATABASE demo;

-- %%
DESCRIBE DATABASE EXTENDED demo;

-- %%
SELECT current_database();

-- %%
SHOW TABLES;

-- %%
SHOW TABLES IN demo;

-- %%
USE demo;

-- %%
SELECT current_database();

-- %% [markdown]
-- ### Tablas Administradas(Managed Tables)

-- %% [markdown]
-- ### Objetivos
-- 1. Crear una "Tabla Administrada(Managed Table)" con Python
-- 2. Crear una "Tabla Administrada(Managed Table)" con SQL
-- 3. Efecto de eliminar una Tabla Administrada

-- %%
%run "../includes/configuration"

-- %% [markdown]
-- #### Crear una "Tabla Administrada(Managed Table)" con Python

-- %%
%python
results_movie_genre_language = spark.read.parquet(f"{gold_folder_path}/results_movie_genre_language")

-- %%
%python
results_movie_genre_language.write.format("delta").saveAsTable("demo.results_movie_genre_language_python")

-- %%
USE demo;
SHOW TABLES;

-- %%
DESCRIBE results_movie_genre_language_python;

-- %%
DESCRIBE EXTENDED results_movie_genre_language_python;

-- %%
SELECT * FROM results_movie_genre_language_python WHERE genre_name = 'Adventure'

-- %% [markdown]
-- #### Crear una "Tabla Administrada(Managed Table)" con SQL

-- %%
CREATE TABLE demo.results_movie_genre_language_sql
AS
SELECT * FROM results_movie_genre_language_python WHERE genre_name = 'Adventure'

-- %%
SELECT * FROM results_movie_genre_language_sql

-- %%
SHOW TABLES IN demo

-- %% [markdown]
-- #### Efecto de eliminar una Tabla Administrada

-- %%
DROP TABLE IF EXISTS results_movie_genre_language_sql

-- %%
SHOW TABLES IN demo

-- %% [markdown]
-- ### Tablas Externas(External Tables)

-- %% [markdown]
-- ### Objetivos
-- 1. Crear una "Tabla Externa(External Table)" con Python
-- 2. Crear una "Tabla Externa(External Table)" con SQL
-- 3. Efecto de eliminar una Tabla Externa

-- %% [markdown]
-- #### Crear una "Tabla Externa(External Table)" con Python

-- %%
%run "../includes/configuration"

-- %%
%python
results_movie_genre_language.write.format("delta").option("path",f"{gold_folder_path}/results_movie_genre_language_py").saveAsTable("demo.results_movie_genre_language_py")

-- %%
DESC EXTENDED demo.results_movie_genre_language_py

-- %%
SELECT * FROM demo.results_movie_genre_language_py

-- %% [markdown]
-- #### Crear una "Tabla Externa(External Table)" con SQL

-- %%
CREATE TABLE demo.results_movie_genre_language_sql(
  title STRING,
  duration_time INT,
  release_date DATE,
  vote_average FLOAT,
  language_name STRING,
  genre_name STRING,
  created_date TIMESTAMP
)
USING PARQUET
LOCATION "abfss://gold@moviee.dfs.core.windows.net/results_movie_genre_language_sql"

-- %%
SHOW TABLES IN demo

-- %%
INSERT INTO demo.results_movie_genre_language_sql
SELECT * FROM demo.results_movie_genre_language_py
WHERE genre_name = 'Adventure'

-- %%
DROP TABLE IF EXISTS demo.results_movie_genre_language_sql

-- %% [markdown]
-- ### Vistas(Views)

-- %% [markdown]
-- ### Objetivos
-- 1. Crear Vista Temporal Local
-- 2. Crear Vista Temporal Global
-- 3. Crear Vista Permanente

-- %%
SELECT current_database()

-- %%
USE demo

-- %% [markdown]
-- #### Crear Vista Temporal Local

-- %%
CREATE OR REPLACE TEMP VIEW v_results_movies_genres_language
AS
SELECT * FROM demo.results_movie_genre_language_py
WHERE genre_name = 'Adventure'

-- %%
SELECT * FROM v_results_movies_genres_language

-- %% [markdown]
-- #### Crear Vista Temporal Global

-- %%
CREATE OR REPLACE GLOBAL TEMP VIEW gv_results_movies_genres_language
AS
SELECT * FROM demo.results_movie_genre_language_py
WHERE genre_name = 'Adventure'

-- %%
SELECT * FROM global_temp.gv_results_movies_genres_language

-- %% [markdown]
-- #### Crear Vista Permanente

-- %%
CREATE OR REPLACE VIEW pv_results_movies_genres_language
AS
SELECT * FROM demo.results_movie_genre_language_py
WHERE genre_name = 'Adventure'

-- %%
SHOW TABLES IN demo
