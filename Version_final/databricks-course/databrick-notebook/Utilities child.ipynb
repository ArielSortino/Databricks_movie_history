# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("p_msg","","Parametro de entrada")

# %%
v_msg = dbutils.widgets.get("p_msg")

# %%
print("Soy el hijo del notebook: Utilities introducción. " + v_msg)

# %%
dbutils.notebook.exit("Ejecución con éxito")
